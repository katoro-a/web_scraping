# %%
import pandas as pd 
import os
import re 
pd.set_option('display.max_columns',None) 
pd.set_option('display.max_rows',None) 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# https://www.kaggle.com/datasets/ekrembayar/fifa-21-complete-player-dataset?resource=download

# %% [markdown]
# Try scraping the original website yourself
# - https://sofifa.com/?showCol%5B%5D=ae&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=gc&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=sho&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def&showCol%5B%5D=phy&showCol%5B%5D=pi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=bp&showCol%5B%5D=bo&showCol%5B%5D=gu&showCol%5B%5D=hi&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=he&showCol%5B%5D=fi&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=cu&showCol%5B%5D=dr&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=to&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=ag&showCol%5B%5D=ln&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=te&showCol%5B%5D=ju&showCol%5B%5D=pe&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=ar&showCol%5B%5D=cm&showCol%5B%5D=sr&showCol%5B%5D=st&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=td&showCol%5B%5D=sl&showCol%5B%5D=gh&showCol%5B%5D=gp&showCol%5B%5D=gd&showCol%5B%5D=gr&showCol%5B%5D=tg&showCol%5B%5D=pac

# %%
a = pd.read_csv('/Users/k/Desktop/fifa21_male2.csv')

# %%
a.head(5)
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                           Club Logo  \
# ...

# %%
a.tail(5)
# Out:
#            ID             Name  Age  OVA         Nationality           Club  \
# 17120  259088       A. Medioub   22   64              France     CD Tondela
# 17121  259090       W. Rickard   18   56               Wales        Burnley
# 17122  259091       C. Barrett   18   56             England        Burnley
# 17123  259101   J. Gazibegović   20   62  Bosnia Herzegovina  SK Sturm Graz
# 17124  259105  Pablo Rodríguez   18   59               Spain          Lecce
#
#        BOV   BP Position                                       Player Photo  \
# 17120   66   CB       CB  https://cdn.sofifa.com/players/259/088/20_120.png
# 17121   58  CAM   CAM CM  https://cdn.sofifa.com/players/259/090/20_120.png
# 17122   56   RB       RB  https://cdn.sofifa.com/players/259/091/20_120.png
# 17123   62   RB    RB LB  https://cdn.sofifa.com/players/259/101/20_120.png
# 17124   61   ST       ST  https://cdn.sofifa.com/players/259/105/20_120.png
#
# ...

# %%
a.shape
# Out:
# (17125, 107)

# %%
print(a.columns)
# Out:
# Index(['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP',
#        'Position', 'Player Photo',
#        ...
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'Gender'],
#       dtype='object', length=107)

# %%
# steps to follow take a look at the data basic histograms, do a data describe 
# identify what you want to focus on  
# then start cleaning, change the column names first 
# identify columns you can drop immediatly 
# drop columns with more than .8 nans

# %%
a.dtypes
# Out:
# ID                    int64
# Name                 object
# Age                   int64
# OVA                   int64
# Nationality          object
# Club                 object
# BOV                   int64
# BP                   object
# Position             object
# Player Photo         object
# Club Logo            object
# Flag Photo           object
# POT                   int64
# Team & Contract      object
# Height               object
# Weight               object
# foot                 object
# Growth                int64
# Joined               object
# Loan Date End        object
# Value                object
# Wage                 object
# Release Clause       object
# Contract             object
# Attacking             int64
# Crossing              int64
# Finishing             int64
# Heading Accuracy      int64
# Short Passing         int64
# Volleys             float64
# Skill                 int64
# Dribbling             int64
# Curve               float64
# ...

# %%
# a.select_dtypes('object')

# %%
a.head(5)
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                           Club Logo  \
# ...

# %%
# lower case the column headings 
a.columns=a.columns.str.lower() 
a.head(3) 
# then apply a snake case so spaces are filled in with a _ 
     #TRY
# Out:
#    id         name  age  ova nationality           club  bov   bp  \
# 0   2  G. Pasquale   33   69       Italy        Udinese   71  LWB
# 1  16  Luis García   37   71       Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71     England  Coventry City   71  CAM
#
#        position                                       player photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
#
#                                         club logo  \
# 0    https://cdn.sofifa.com/teams/55/light_60.png
# 1  https://cdn.sofifa.com/teams/2013/light_60.png
# 2  https://cdn.sofifa.com/teams/1800/light_60.png
#
#                                 flag photo  pot            team & contract  \
# 0      https://cdn.sofifa.com/flags/it.png   69        Udinese 2008 ~ 2016
# ...

# %%
a['gender'].value_counts()
# dont need this column redundant
# Out:
# Male    17125
# Name: gender, dtype: int64

# %%
# identify columns you can drop right off the bat
a=a.drop(['player photo','club logo','flag photo','gender'],axis=1)

# %%
a.shape
# Out:
# (17125, 103)

# %%
# more than 90% nans

# %%
pd.DataFrame(a.isna().sum()/len(a))
# Out:
#                          0
# id                0.000000
# name              0.000000
# age               0.000000
# ova               0.000000
# nationality       0.000000
# club              0.001343
# bov               0.000000
# bp                0.000000
# position          0.024117
# pot               0.000000
# team & contract   0.000000
# height            0.000000
# weight            0.000000
# foot              0.000000
# growth            0.000000
# joined            0.003387
# loan date end     0.946861
# value             0.000000
# wage              0.000000
# release clause    0.000000
# contract          0.000000
# attacking         0.000000
# crossing          0.000000
# finishing         0.000000
# heading accuracy  0.000000
# short passing     0.000000
# volleys           0.003387
# skill             0.000000
# dribbling         0.000000
# curve             0.003387
# fk accuracy       0.000000
# long passing      0.000000
# ball control      0.000000
# ...

# %%
a.head(5)
# Out:
#    id         name  age  ova            nationality           club  bov   bp  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        position  pot            team & contract height  weight   foot  growth  \
# 0            LM   69        Udinese 2008 ~ 2016   6'0"  181lbs   Left       0
# 1    CM CAM CDM   71      KAS Eupen 2014 ~ 2019  5'10"  143lbs  Right       0
# 2  CAM RM RW LM   71  Coventry City 2016 ~ 2020   5'9"  161lbs  Right       0
# 3           NaN   82            Sunderland 2009  5'11"  165lbs  Right      14
# 4        CM CAM   81    Vissel Kobe 2018 ~ 2021   5'7"  150lbs  Right       0
#
# ...

# %%
a['nationality'].value_counts()
# Out:
# England                     1707
# Germany                     1154
# Spain                       1121
# France                       990
# Brazil                       857
# Argentina                    778
# Italy                        565
# Netherlands                  475
# Portugal                     365
# United States                358
# Mexico                       345
# Uruguay                      335
# Colombia                     305
# Japan                        295
# Poland                       291
# Scotland                     281
# Republic of Ireland          278
# Belgium                      263
# Norway                       260
# Sweden                       260
# Denmark                      258
# Austria                      245
# Turkey                       226
# Switzerland                  211
# Paraguay                     180
# Chile                        180
# Romania                      166
# Korea Republic               155
# ...

# %%
categorical = a.select_dtypes(np.object) 
categorical.head(5) 
# note that a good portion are not onjects
# Out:
#           name            nationality           club   bp      position  \
# 0  G. Pasquale                  Italy        Udinese  LWB            LM
# 1  Luis García                  Spain      KAS Eupen   CM    CM CAM CDM
# 2      J. Cole                England  Coventry City  CAM  CAM RM RW LM
# 3     D. Yorke  Trinidad &amp; Tobago     Sunderland   ST           NaN
# 4      Iniesta                  Spain    Vissel Kobe  CAM        CM CAM
#
#              team & contract height  weight   foot        joined  \
# 0        Udinese 2008 ~ 2016   6'0"  181lbs   Left   Jul 1, 2008
# 1      KAS Eupen 2014 ~ 2019  5'10"  143lbs  Right  Jul 19, 2014
# 2  Coventry City 2016 ~ 2020   5'9"  161lbs  Right   Jan 7, 2016
# 3            Sunderland 2009  5'11"  165lbs  Right           NaN
# 4    Vissel Kobe 2018 ~ 2021   5'7"  150lbs  Right  Jul 16, 2018
#
#   loan date end  value  wage release clause     contract  w/f  sm     a/w  \
# ...

# %%
def value_counts(x):
    a[x].value_counts()
