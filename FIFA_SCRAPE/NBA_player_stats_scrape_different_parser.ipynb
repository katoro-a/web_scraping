# %%
from bs4 import BeautifulSoup 
from time import sleep 
import requests 
import pandas as pd

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
url = 'https://www.nba.com/stats/player/101106' 
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
#soup = BeautifulSoup(response.content,'html.parser')
soup = BeautifulSoup(response.content,'lxml')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find('body')
# Out:
# <body><div id="__next"><div data-esi="true" style="display:none"><div>
# <script>
#       var _esi = {
#         country: "US",
#         tz: "EST",
#         region: "FL",
#         browser: "OTHER",
#         os: "OTHER",
#         device: "computer",
#         isMobile: "false",
#         isDomestic: "true"
#       };
#     </script>
# ...

# %%
# try the website below to see if you can scrape it using this

# %%
https://www.google.com/search?q=scrape+nba+stats+python&rlz=1C5CHFA_enCO985US990&oq=scraping+nba+stats+&aqs=chrome.1.69i57j0i22i30l3j0i390.4823j1j7&sourceid=chrome&ie=UTF-8#kpvalbx=_myKaYoH4D86TwbkPp7qviAM16
